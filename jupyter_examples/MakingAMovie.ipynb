# %% [markdown]
# # Setup
#
# We begin by importing what we need, and loading a simulation. We rescale the time for convenience so that a simulation time of 1 corresponds to one orbit of the outermost planet.

# %%
import sys
sys.path.append('../')
import systemsounds as ss
import numpy as np
import rebound
filename = "../binaries/trappist.bin"
#filename = "../binaries/newsystem.bin"
sim = rebound.Simulation.from_file(filename)
sim.t = 0
ss.rescale_time(sim, sim.particles[-1].P)

# %% [markdown]
# We first add a `FrameRecorder` to write frames for the movie. We have to choose how much simulation time will correspond to one second in the movie. Here we choose for each unit of time (outer planet orbits) to correspond to two seconds of movie time. We also record all the transits and conjunctions.

# %%
frames = ss.FrameRecorder(sim, time_per_sec=0.5)
transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))

# %% [markdown]
# As an overview, the approach is for the `FrameRecorder` to record events at all the moments when we need to write a frame, and we'll later write a function to generate each of those frames. This makes it easier to parallelize, which is nice since generating individual plots with matplotlib is quite slow.
#
# With that in mind, we can also add any metadata to the `FrameRecorder` that we later want to use to write the movie frames. This will be saved in each of the frame events, e.g.:

# %%
frames.color = ['None','red','darkorange','forestgreen','cyan','deepskyblue','violet','darkviolet']

# %% [markdown]
# We'll make a simple movie where we only display the outer 3 planets. We do that by changing `frames.plotparticles` to store the particles we want displayed.

# %%
frames.plotparticles = [5,6,7]
sim.integrate(tmax=2) # integrate for two outer planet orbits
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
# ----> 2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
#       3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
#       2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
# ----> 3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
# ----> 2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
#       3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
#       2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
# ----> 3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
# ----> 2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
#       3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
#       2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
# ----> 3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
# ----> 2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
#       3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
#       2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
# ----> 3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
# ----> 2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
#       3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
#       2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
# ----> 3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
# ----> 2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
#       3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
#       2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
# ----> 3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
# ----> 2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
#       3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
#       2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
# ----> 3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
# ----> 2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
#       3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
#       2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
# ----> 3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
# ----> 2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
#       3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
#       2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
# ----> 3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
# ----> 2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
#       3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
#       2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
# ----> 3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
# ----> 2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
#       3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
#       2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
# ----> 3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
# ----> 2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
#       3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
#       2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
# ----> 3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
# ----> 2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
#       3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
#       2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
# ----> 3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
# ----> 2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
#       3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
#       2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
# ----> 3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
# ...
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
# ----> 2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
#       3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
#       2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
# ----> 3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
# ----> 2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
#       3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
#       2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
# ----> 3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
# ----> 2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
#       3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
#       2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
# ----> 3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
# ----> 2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
#       3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
#       2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
# ----> 3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
# ----> 2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
#       3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in heartbeat(reb_sim)
#      35     def heartbeat(reb_sim):
#      36         oldhb(reb_sim)
# ---> 37         func(reb_sim)
#      38     sim.heartbeat = heartbeat                               # update ctypes function wrapper in sim
#      39
#
# /MATT/5 System Sounds/systemsounds/systemsounds.py in check_for_root_crossings(reb_sim)
#      57             ps = sim.particles
#      58             for target in self.targets:
# ---> 59                 val = rootfunc(sim, target)
#      60                 if self._oldvals[target] is not None:           # not first call
#      61                     if self._oldvals[target] < 0 and val >= 0:   # crossed from negative to positive
#
# <ipython-input-2-e90c9e6ea1af> in <lambda>(sim, i)
#       1 frames = ss.FrameRecorder(sim, time_per_sec=0.5)
#       2 transits = ss.EventRecorder(sim, lambda sim, i: sim.particles[i].y, targets=range(1,8))
# ----> 3 conjunctions = ss.EventRecorder(sim, lambda sim, i: np.sin(sim.particles[i].theta - sim.particles[i+1].theta), targets=range(1,7))
#
# /Applications/anaconda/envs/venv/lib/python3.6/site-packages/rebound/simulation.py in __getitem__(self, key)
#    1737                 key += self.sim.N
#    1738             if key < 0 or key >= self.sim.N:
# -> 1739                 raise AttributeError("Index {0} used to access particles out of range.".format(key))
#    1740             return self._ps[key]
#    1741
#
# AttributeError: Index 4 used to access particles out of range.

# %% [markdown]
# We now have events for all the frames in the movie in `frames.events`, all the transits in `transits.events` and conjunctions in `conjunctions.events`.

# %% [markdown]
# # Writing the movie frames
#
# We now need to write a function that writes movie frames for each of the events. Each frame event stores basic information for the frame in a dictionary, notably a filename to a binary that stores the simulation at the appropriate time for the frame, as well as any metadata we have added before/between calls to sim.integrate (e.g. the `color` field we added above). We can see this in the first frame event:

# %%
frames.events[0]
# Out:
# {'color': ['None',
#   'red',
#   'darkorange',
#   'forestgreen',
#   'cyan',
#   'deepskyblue',
#   'violet',
#   'darkviolet'],
#  'elapsed_time': 0.03537080119148124,
#  'filename': 'tmp/binaries/frame0.bin',
#  'fps': 30,
#  'frame_ctr': 0,
#  'plotparticles': [5, 6, 7],
#  'target': None,
#  'time': 0.016666662112231917,
#  'time_per_sec': 0.5}

# %% [markdown]
# We now need to write a function that will write a movie frame from this information. Below is a simple one we could use, where we take the variables we need, and leave the remaining dictionary entries unspecified in kwargs. We'll be writing many frames (to the tmp/pngs/ directory), so it's important to close the figures after each one.

# %%
import matplotlib.pyplot as plt
def write_png(params):
    sim = rebound.Simulation.from_file(params['filename'])
    plotparticles = params['plotparticles']       # particles that should be displayed
    color = params['color']                       # colors for each of the particles (including the star)
    coloriterator = [color[i] for i in plotparticles]
    fig = rebound.OrbitPlot(sim, figsize=(8,8), plotparticles=params['plotparticles'],color=coloriterator)
    fig.axes[0].axis('off') # turn off axes
    fig.savefig('tmp/pngs/{0:0=5d}.png'.format(params['frame_ctr']))
    plt.close(fig)

# %% [markdown]
# We now write all the frames using our function. Making matplotlib plots is not optimized for efficiency, so it's quite slow. We therefore generate them in parallel.

# %%
# %%time
from subprocess import call
call("rm -f tmp/pngs/*", shell=True)
pool = rebound.InterruptiblePool()
res = pool.map(write_png, frames.events)
# Out:
# CPU times: user 11.1 ms, sys: 24.2 ms, total: 35.4 ms
# Wall time: 5.66 s

# %% [markdown]
# # Outputting a movie file
#
# You now have all the frames for the movie in `systemsounds/jupyter_examples/tmp/pngs`, and can stitch them together into a movie using your favorite software. For some ideas and options, see [MovieEditingSoftware.ipynb](MovieEditingSoftware.ipynb)
#
# # More advanced example
#
# Everyone will want to do something slightly differently, so rather than building up a complicated framework with many options, the idea is that people can contribute examples to this repository that others can draw on to make their own custom movies. We're looking forward to seeing what people come up with! For a more complicated example see [TRAPPIST1.ipynb](TRAPPIST1.ipynb)
